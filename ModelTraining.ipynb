# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split # split  data into training and testing sets
from sklearn.preprocessing import scale # scale and center data
from sklearn.model_selection import GridSearchCV # this will do cross validation
from sklearn.metrics import confusion_matrix # this creates a confusion matrix
from sklearn.metrics import plot_confusion_matrix # draws a confusion matrix
from sklearn.decomposition import PCA # to perform PCA to plot the data
from sklearn import preprocessing
from sklearn import metrics

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv("cardio_train.csv",sep=';')
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# age in days
# gender 1-women, 2-men
# height in cm
# weight in kg
# ap_hi Systolic blood pressure
# ap_lo Diastolic blood pressure
# cholestrol 1: normal, 2: above normal, 3: well above normal
# gluc 1: normal, 2: above normal, 3: well above normal
# cardio target variable

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df[df.duplicated()].head()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 10562  20495       1     165    70.0    120     80            1     1      0
# 21784  16793       1     165    68.0    120     80            1     1      0
# 38505  18988       1     164    65.0    120     80            1     1      0
# 40365  14552       1     158    64.0    120     80            1     1      0
# 42450  18353       1     169    67.0    120     80            1     1      0
#
#        alco  active  cardio
# 10562     0       1       0
# 21784     0       1       0
# 38505     0       1       0
# 40365     0       1       0
# 42450     0       1       0

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df['age']=df['age']//365
df['age'].astype('int')
df.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50       2     168    62.0    110     80            1     1      0     0
# 1   55       1     156    85.0    140     90            3     1      0     0
# 2   51       1     165    64.0    130     70            3     1      0     0
# 3   48       2     169    82.0    150    100            1     1      0     0
# 4   47       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
df['height']=df['height']*0.0328
df['height'].astype('float')
df['height']=df['height'].round(decimals=1)
df.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50       2     5.5    62.0    110     80            1     1      0     0
# 1   55       1     5.1    85.0    140     90            3     1      0     0
# 2   51       1     5.4    64.0    130     70            3     1      0     0
# 3   48       2     5.5    82.0    150    100            1     1      0     0
# 4   47       1     5.1    56.0    100     60            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
#print(plt.boxplot(df['age']))
print(plt.boxplot(df['weight']))
#print(plt.boxplot(df['ap_hi']))
#print(plt.boxplot(df['ap_lo']))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D object at 0x0000011E70A67310>, <matplotlib.lines.Line2D object at 0x0000011E70A67670>], 'caps': [<matplotlib.lines.Line2D object at 0x0000011E70A679D0>, <matplotlib.lines.Line2D object at 0x0000011E70A67D30>], 'boxes': [<matplotlib.lines.Line2D object at 0x0000011E70A4FF70>], 'medians': [<matplotlib.lines.Line2D object at 0x0000011E70A750D0>], 'fliers': [<matplotlib.lines.Line2D object at 0x0000011E70A753D0>], 'means': []}

# %%
#df['weight']=df['weight'].astype('int')
#df[(df['weight']<=40) | (df['weight']>115)]
#df.drop(df[df['weight']<=40].index,inplace=True)
#df.drop(df[df['weight']>115].index,inplace=True)

# %%
df.dtypes
# Out:
# age              int64
# gender           int64
# height         float64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
X=df.drop(['cardio'], axis=1).copy()
X.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50       2     5.5    62.0    110     80            1     1      0     0
# 1   55       1     5.1    85.0    140     90            3     1      0     0
# 2   51       1     5.4    64.0    130     70            3     1      0     0
# 3   48       2     5.5    82.0    150    100            1     1      0     0
# 4   47       1     5.1    56.0    100     60            1     1      0     0
#
#    active
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0

# %%
y=df['cardio'].copy()
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: cardio, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.15381528 0.00674812 0.15568751 0.26386389 0.21321574 0.12855788
#  0.05018843 0.01291946 0.00459712 0.00471368 0.00569288]

# %%
df.corr()
# Out:
#                   age    gender    height    weight     ap_hi     ap_lo  \
# age          1.000000 -0.022863 -0.080023  0.053576  0.020855  0.017619
# gender      -0.022863  1.000000  0.498928  0.155320  0.005996  0.015241
# height      -0.080023  0.498928  1.000000  0.292342  0.005170  0.006770
# weight       0.053576  0.155320  0.292342  1.000000  0.030693  0.043695
# ap_hi        0.020855  0.005996  0.005170  0.030693  1.000000  0.016084
# ap_lo        0.017619  0.015241  0.006770  0.043695  0.016084  1.000000
# cholesterol  0.154023 -0.035915 -0.048130  0.141679  0.023768  0.024004
# gluc         0.098391 -0.020558 -0.018238  0.106790  0.011833  0.010794
# smoke       -0.047664  0.338131  0.188000  0.067725 -0.000928  0.005177
# alco        -0.029767  0.170950  0.094712  0.067071  0.001403  0.010594
# active      -0.009994  0.005917 -0.005809 -0.016863 -0.000031  0.004784
# cardio       0.238020  0.008037 -0.009984  0.181599  0.054475  0.065717
#
#              cholesterol      gluc     smoke      alco    active    cardio
# age             0.154023  0.098391 -0.047664 -0.029767 -0.009994  0.238020
# gender         -0.035915 -0.020558  0.338131  0.170950  0.005917  0.008037
# height         -0.048130 -0.018238  0.188000  0.094712 -0.005809 -0.009984
# weight          0.141679  0.106790  0.067725  0.067071 -0.016863  0.181599
# ap_hi           0.023768  0.011833 -0.000928  0.001403 -0.000031  0.054475
# ap_lo           0.024004  0.010794  0.005177  0.010594  0.004784  0.065717
# cholesterol     1.000000  0.451539  0.010298  0.035718  0.009927  0.221119
# gluc            0.451539  1.000000 -0.004799  0.011214 -0.006761  0.089268
# smoke           0.010298 -0.004799  1.000000  0.340077  0.025870 -0.015533
# alco            0.035718  0.011214  0.340077  1.000000  0.025486 -0.007366
# active          0.009927 -0.006761  0.025870  0.025486  1.000000 -0.035666
# cardio          0.221119  0.089268 -0.015533 -0.007366 -0.035666  1.000000

# %%
#X = preprocessing.StandardScaler().fit(X).transform(X)
#get_score(SVC(), X_train, X_test, y_train, y_test)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)
X_test.head()
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 38418   43       2     5.6    64.0    100     60            1     1      0
# 63343   54       2     5.7    75.0    120     80            1     1      0
# 52736   40       1     5.3    53.0    100     60            1     1      0
# 47714   57       2     5.8    65.0    120     80            1     1      0
# 52043   57       1     5.7    75.0    140     80            2     1      0
#
#        alco  active
# 38418     0       1
# 63343     0       1
# 52736     0       0
# 47714     0       0
# 52043     1       1

# %%
y_test.head()
# Out:
# 38418    0
# 63343    0
# 52736    0
# 47714    0
# 52043    1
# Name: cardio, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7)
def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)
print(get_score(LogisticRegression(), X_train, X_test, y_train, y_test))
print(get_score(RandomForestClassifier(n_estimators=20), X_train, X_test, y_train, y_test))
print(get_score(KNeighborsClassifier(n_neighbors=11), X_train, X_test, y_train, y_test))
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.706013490339545
# 0.7000114324911398
# 0.7165313821881788

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(LogisticRegression(),X,y,cv=10,scoring='accuracy').mean())
print(cross_val_score(RandomForestClassifier(n_estimators=20),X,y,cv=10,scoring='accuracy').mean())
print(cross_val_score(KNeighborsClassifier(n_neighbors=9),X,y,cv=10,scoring='accuracy').mean())
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7087431195249929
# 0.6992110508472111
# 0.7113866666329011

# %%
LR = LogisticRegression()
LR.fit(X_train, y_train)
plot_confusion_matrix(LR, X_test, y_test, display_labels=['Does not have CVD', 'Has CVD'])
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
LR.predict(X_test)
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
import pickle
pickle_out=open("LR.pkl","wb")
pickle.dump(LR, pickle_out)
